# %%
import pandas as pd

temp = pd.DataFrame({'A': [1, 2, 3, 4],
                     'B': [10, 20, 30, 40],
                     'C': ['20/1/2025', '22/1/2025', '25/1/2025', '27/1/2025']})

# %%
print(temp)
# Out:
#    A   B          C
# 0  1  10  20/1/2025
# 1  2  20  22/1/2025
# 2  3  30  25/1/2025
# 3  4  40  27/1/2025

# %%
temp.dtypes
# Out:
# A     int64
# B     int64
# C    object
# dtype: object

# %% [markdown]
# temp['C'] = pd.to_datetime(temp['C'])
# temp.dtypes

# %%
temp['C'] = pd.to_datetime(temp['C']) 
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp['C']=pd.to_datetime(temp['C'],format="%d/%m/%y")
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp['A'] = temp['A'].astype(str)
print(temp)
# Out:
#    A   B          C
# 0  1  10 2025-01-20
# 1  2  20 2025-01-22
# 2  3  30 2025-01-25
# 3  4  40 2025-01-27

# %%
uber_data.head()
# Out:
#           START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0 2016-01-01 21:11:00  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1 2016-01-02 01:25:00   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2 2016-01-02 20:25:00  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3 2016-01-05 17:31:00  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4 2016-01-06 14:42:00  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
unique_cities = uber_data['STOP*'].unique()
print("Unique cities in the dataset:")
print(unique_cities)
# Out:
# Unique cities in the dataset:
# ['Fort Pierce' 'West Palm Beach' 'Palm Beach' 'Cary' 'Morrisville'
#  'New York' 'Queens' 'East Harlem' 'NoMad' 'Midtown' 'Midtown East'
#  'Hudson Square' 'Lower Manhattan' "Hell's Kitchen" 'Queens County'
#  'Gulfton' 'Downtown' 'Houston' 'Jamestown Court' 'Durham' 'Whitebridge'
#  'Lake Wellingborough' 'Raleigh' 'Umstead' 'Hazelwood' 'Westpark Place'
#  'Meredith Townes' 'Leesville Hollow' 'Apex' 'Chapel Hill'
#  'Williamsburg Manor' 'Macgregor Downs' 'Edgehill Farms' 'Northwoods'
#  'Tanglewood' 'Preston' 'Walnut Terrace' 'Jackson Heights' 'East Elmhurst'
#  'Midtown West' 'Long Island City' 'Jamaica' 'Unknown Location' 'Colombo'
#  'Nugegoda' 'Katunayaka' 'Islamabad' 'R?walpindi' 'Noorpur Shahan'
#  'Heritage Pines' 'Waverly Place' 'Wayne Ridge' 'Depot Historic District'
#  'Weston' 'West University' 'South Congress' 'Arts District'
#  'Congress Ave District' 'Red River District' 'The Drag'
# ...

# %%
print("count of the records in the dataset:")
uber_data['START*'].value_counts()
# Out:
# count of the records in the dataset:
# START*
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: count, Length: 177, dtype: int64

# %%
print("unique starts in the dataset:")
uber_data['START*'].unique()
# Out:
# unique starts in the dataset:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
# ...

# %%
a=uber_data[(uber_data['MILES*']>50) & (uber_data['MILES*']<=100)]
a
# Out:
#             START_DATE*         END_DATE* CATEGORY*            START*  \
# 4   2016-01-06 14:42:00    1/6/2016 15:49  Business       Fort Pierce
# 251 2016-03-19 19:33:00   3/19/2016 20:39  Business         Galveston
# 295 2016-04-02 12:21:00    4/2/2016 14:47  Business         Kissimmee
# 296 2016-04-02 16:57:00    4/2/2016 18:09  Business     Daytona Beach
# 707 2016-08-24 13:01:00   8/24/2016 15:25  Business  Unknown Location
# 710 2016-08-25 17:19:00   8/25/2016 19:20  Business  Unknown Location
# 726 2016-08-27 14:01:00   8/27/2016 15:44  Business            Lahore
# 751 2016-09-06 17:49:00    9/6/2016 17:49  Business  Unknown Location
# 871 2016-10-28 20:13:00  10/28/2016 22:00  Business         Asheville
# 873 2016-10-29 17:13:00  10/29/2016 19:19  Business        Hayesville
# 880 2016-10-30 13:24:00  10/30/2016 14:37  Business       Bryson City
#
#                 STOP*  MILES*        PURPOSE*
# 4     West Palm Beach    63.7  Customer Visit
# ...

# %%
a=uber_data[(uber_data['START*']=="New York")]
a
# Out:
#             START_DATE*        END_DATE* CATEGORY*    START*  \
# 10  2016-01-10 15:08:00  1/10/2016 15:51  Business  New York
# 22  2016-01-12 16:02:00  1/12/2016 17:00  Business  New York
# 106 2016-02-14 16:35:00  2/14/2016 17:02  Business  New York
# 423 2016-06-10 15:19:00  6/10/2016 16:28  Business  New York
#
#                 STOP*  MILES* PURPOSE*
# 10             Queens    10.8  Meeting
# 22      Queens County    15.1  Meeting
# 106  Long Island City    13.0  Meeting
# 423           Jamaica    16.3  Meeting

# %%
a=uber_data[uber_data['MILES*']>15]
a.iloc[:,3:6]
# Out:
#                 START*             STOP*   MILES*
# 4          Fort Pierce   West Palm Beach     63.7
# 9              Jamaica          New York     16.5
# 22            New York     Queens County     15.1
# 25             Houston           Houston     21.9
# 34                Cary           Raleigh     17.1
# ...                ...               ...      ...
# 1089  Unknown Location  Unknown Location     32.3
# 1092  Unknown Location  Unknown Location     23.2
# 1152  Unknown Location  Unknown Location     16.2
# 1154           Gampaha         Ilukwatta     48.2
# 1155               NaN               NaN  12204.7
#
# [155 rows x 3 columns]

# %%
a=uber_data[uber_data['START*'].isin(['New York','Cary']) & uber_data['STOP*'].isin(['New York','Cary'])] 
a
# Out:
#              START_DATE*         END_DATE* CATEGORY* START* STOP*  MILES*  \
# 7    2016-01-07 13:27:00    1/7/2016 13:33  Business   Cary  Cary     0.8
# 30   2016-01-18 14:55:00   1/18/2016 15:06  Business   Cary  Cary     4.8
# 37   2016-01-21 14:25:00   1/21/2016 14:29  Business   Cary  Cary     1.6
# 38   2016-01-21 14:43:00   1/21/2016 14:51  Business   Cary  Cary     2.4
# 39   2016-01-21 16:01:00   1/21/2016 16:06  Business   Cary  Cary     1.0
# 43   2016-01-26 17:17:00   1/26/2016 17:22  Business   Cary  Cary     1.4
# 44   2016-01-26 17:27:00   1/26/2016 17:29  Business   Cary  Cary     0.5
# 45   2016-01-27 09:24:00    1/27/2016 9:31  Business   Cary  Cary     1.8
# 53   2016-01-29 09:31:00    1/29/2016 9:45  Business   Cary  Cary     4.6
# 54   2016-01-29 10:56:00   1/29/2016 11:07  Business   Cary  Cary     5.2
# 65   2016-02-02 13:51:00    2/2/2016 14:06  Business   Cary  Cary     6.0
# 66   2016-02-02 14:38:00    2/2/2016 14:42  Business   Cary  Cary     1.6
# ...

# %%
a=uber_data[uber_data['START*'].isin(['New York','Cary','Lahore	']) & uber_data['STOP*'].isin(['Daytona Beach','Houston','Topton']) & ((uber_data['MILES*']>10) & (uber_data['MILES*']<=20))] 
a
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
uber_data['START_DATE*'] = pd.to_datetime(uber_data['START_DATE*'], errors='coerce')

jan_data = uber_data[(uber_data['START_DATE*'].dt.month == 1 )& (uber_data['START_DATE*'].dt.year == 2016)]

jan_data
# Out:
#            START_DATE*        END_DATE* CATEGORY*       START*  \
# 0  2016-01-01 21:11:00   1/1/2016 21:17  Business  Fort Pierce
# 1  2016-01-02 01:25:00    1/2/2016 1:37  Business  Fort Pierce
# 2  2016-01-02 20:25:00   1/2/2016 20:38  Business  Fort Pierce
# 3  2016-01-05 17:31:00   1/5/2016 17:45  Business  Fort Pierce
# 4  2016-01-06 14:42:00   1/6/2016 15:49  Business  Fort Pierce
# ..                 ...              ...       ...          ...
# 56 2016-01-29 13:24:00  1/29/2016 13:47  Business       Durham
# 57 2016-01-29 18:31:00  1/29/2016 18:52  Business         Cary
# 58 2016-01-29 21:21:00  1/29/2016 21:40  Business         Apex
# 59 2016-01-30 16:21:00  1/30/2016 16:33  Business         Cary
# 60 2016-01-30 18:09:00  1/30/2016 18:24  Business         Apex
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# 1       Fort Pierce     5.0              NaN
# 2       Fort Pierce     4.8  Errand/Supplies
# ...

# %%
uber_data['START_DATE*'] = pd.to_datetime(uber_data['START_DATE*'], errors='coerce')

jan_data = uber_data[(uber_data['START_DATE*'].dt.month == 1 )& (uber_data['START_DATE*'].dt.year == 2016) & (uber_data['START*'] == "Cary")]

jan_data
# Out:
#            START_DATE*        END_DATE* CATEGORY* START*        STOP*  MILES*  \
# 7  2016-01-07 13:27:00   1/7/2016 13:33  Business   Cary         Cary     0.8
# 8  2016-01-10 08:05:00   1/10/2016 8:25  Business   Cary  Morrisville     8.3
# 28 2016-01-15 11:43:00  1/15/2016 12:03  Business   Cary       Durham    10.4
# 30 2016-01-18 14:55:00  1/18/2016 15:06  Business   Cary         Cary     4.8
# 34 2016-01-20 10:36:00  1/20/2016 11:11  Business   Cary      Raleigh    17.1
# 37 2016-01-21 14:25:00  1/21/2016 14:29  Business   Cary         Cary     1.6
# 38 2016-01-21 14:43:00  1/21/2016 14:51  Business   Cary         Cary     2.4
# 39 2016-01-21 16:01:00  1/21/2016 16:06  Business   Cary         Cary     1.0
# 43 2016-01-26 17:17:00  1/26/2016 17:22  Business   Cary         Cary     1.4
# 44 2016-01-26 17:27:00  1/26/2016 17:29  Business   Cary         Cary     0.5
# 45 2016-01-27 09:24:00   1/27/2016 9:31  Business   Cary         Cary     1.8
# ...

# %%
a=uber_data[(uber_data['MILES*']>10)&(uber_data['START*'].isin(['Cary','Morris']))]
a.reset_index(inplace=True,drop=True)
a
# Out:
#            START_DATE*         END_DATE* CATEGORY* START*          STOP*  \
# 0  2016-01-15 11:43:00   1/15/2016 12:03  Business   Cary         Durham
# 1  2016-01-20 10:36:00   1/20/2016 11:11  Business   Cary        Raleigh
# 2  2016-01-27 10:19:00   1/27/2016 10:48  Business   Cary        Raleigh
# 3  2016-01-28 12:28:00   1/28/2016 13:00  Business   Cary        Raleigh
# 4  2016-01-29 11:43:00   1/29/2016 12:03  Business   Cary         Durham
# 5  2016-02-01 10:35:00    2/1/2016 11:15  Business   Cary    Chapel Hill
# 6  2016-02-05 11:47:00    2/5/2016 12:07  Business   Cary         Durham
# 7  2016-02-06 16:20:00    2/6/2016 16:53  Business   Cary        Raleigh
# 8  2016-02-11 16:28:00   2/11/2016 17:10  Business   Cary        Raleigh
# 9  2016-02-26 11:35:00   2/26/2016 11:59  Business   Cary         Durham
# 10 2016-03-04 11:46:00    3/4/2016 12:06  Business   Cary         Durham
# 11 2016-03-04 13:40:00    3/4/2016 14:09  Business   Cary        Raleigh
# ...

# %%
uber_data.sort_values(by='MILES*')
uber_data.sort_values(by='MILES*',ascending=False)
# Out:
#              START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155                 NaT               NaN       NaN               NaN
# 269  2016-03-25 16:52:00   3/25/2016 22:22  Business             Latta
# 270  2016-03-25 22:54:00    3/26/2016 1:39  Business      Jacksonville
# 881  2016-10-30 15:22:00  10/30/2016 18:23  Business         Asheville
# 776  2016-09-27 21:01:00    9/28/2016 2:37  Business  Unknown Location
# ...                  ...               ...       ...               ...
# 1121 2016-12-27 12:53:00  12/27/2016 12:57  Business           Kar?chi
# 1110 2016-12-24 22:04:00  12/24/2016 22:09  Business            Lahore
# 44   2016-01-26 17:27:00   1/26/2016 17:29  Business              Cary
# 420  2016-06-08 17:16:00    6/8/2016 17:18  Business              Soho
# 120  2016-02-17 16:38:00   2/17/2016 16:43  Business        Katunayaka
#
#                  STOP*   MILES*         PURPOSE*
# 1155               NaN  12204.7              NaN
# ...

# %%
uber_data.sort_values(by='MILES*')
uber_data.sort_values(by='MILES*',ascending=False)
# Out:
#              START_DATE*         END_DATE* CATEGORY*            START*  \
# 420  2016-06-08 17:16:00    6/8/2016 17:18  Business              Soho
# 44   2016-01-26 17:27:00   1/26/2016 17:29  Business              Cary
# 120  2016-02-17 16:38:00   2/17/2016 16:43  Business        Katunayaka
# 1111 2016-12-25 00:10:00   12/25/2016 0:14  Business            Lahore
# 1110 2016-12-24 22:04:00  12/24/2016 22:09  Business            Lahore
# ...                  ...               ...       ...               ...
# 776  2016-09-27 21:01:00    9/28/2016 2:37  Business  Unknown Location
# 881  2016-10-30 15:22:00  10/30/2016 18:23  Business         Asheville
# 270  2016-03-25 22:54:00    3/26/2016 1:39  Business      Jacksonville
# 269  2016-03-25 16:52:00   3/25/2016 22:22  Business             Latta
# 1155                 NaT               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 420            Tribeca      0.5  Errand/Supplies
# ...

# %%
uber_data.sort_values(by='MILES*')
uber_data.sort_values(by=['START*','MILES*'],ascending=[True,False])
# Out:
#              START_DATE*         END_DATE* CATEGORY*         START*  \
# 906  2016-11-04 21:04:00   11/4/2016 21:20  Business          Agnew
# 911  2016-11-06 10:50:00   11/6/2016 11:04  Business          Agnew
# 908  2016-11-05 08:34:00    11/5/2016 8:43  Business          Agnew
# 910  2016-11-05 19:20:00   11/5/2016 19:28  Business          Agnew
# 879  2016-10-30 12:58:00  10/30/2016 13:18  Business         Almond
# ...                  ...               ...       ...            ...
# 889  2016-11-01 17:35:00   11/1/2016 17:42  Business    Whitebridge
# 890  2016-11-01 19:14:00   11/1/2016 19:20  Business    Whitebridge
# 516  2016-07-05 16:48:00    7/5/2016 16:52  Business    Whitebridge
# 870  2016-10-28 18:13:00  10/28/2016 20:07  Business  Winston Salem
# 1155                 NaT               NaN       NaN            NaN
#
#             STOP*   MILES*         PURPOSE*
# 906          Cory      4.3              NaN
# 911   Renaissance      2.4              NaN
# ...

# %%
import numpy as np
uber_data['MILES_CAT']=np.where(uber_data['MILES*']>100,"Long trip","short trip")
uber_data.head()
# Out:
#           START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0 2016-01-01 21:11:00  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1 2016-01-02 01:25:00   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2 2016-01-02 20:25:00  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3 2016-01-05 17:31:00  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4 2016-01-06 14:42:00  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*   MILES_CAT
# 0     5.1   Meal/Entertain  short trip
# 1     5.0              NaN  short trip
# 2     4.8  Errand/Supplies  short trip
# 3     4.7          Meeting  short trip
# 4    63.7   Customer Visit  short trip

# %%
uber_data['nc'] = 10  
a = uber_data['nc']
uber_data.head()
# Out:
#           START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0 2016-01-01 21:11:00  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1 2016-01-02 01:25:00   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2 2016-01-02 20:25:00  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3 2016-01-05 17:31:00  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4 2016-01-06 14:42:00  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*   MILES_CAT  nc
# 0     5.1   Meal/Entertain  short trip  10
# 1     5.0              NaN  short trip  10
# 2     4.8  Errand/Supplies  short trip  10
# 3     4.7          Meeting  short trip  10
# 4    63.7   Customer Visit  short trip  10

# %%
import numpy as np

uber_data['MILES_CAT'] = np.where(uber_data['MILES*'] <= 10, "Short trip",
                                  np.where((uber_data['MILES*'] > 50) & (uber_data['MILES*'] <= 100), "Medium trip", "Long trip"))

uber_data
# Out:
#              START_DATE*         END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00    1/1/2016 21:17  Business       Fort Pierce
# 1    2016-01-02 01:25:00     1/2/2016 1:37  Business       Fort Pierce
# 2    2016-01-02 20:25:00    1/2/2016 20:38  Business       Fort Pierce
# 3    2016-01-05 17:31:00    1/5/2016 17:45  Business       Fort Pierce
# 4    2016-01-06 14:42:00    1/6/2016 15:49  Business       Fort Pierce
# ...                  ...               ...       ...               ...
# 1151 2016-12-31 13:24:00  12/31/2016 13:42  Business           Kar?chi
# 1152 2016-12-31 15:03:00  12/31/2016 15:38  Business  Unknown Location
# 1153 2016-12-31 21:32:00  12/31/2016 21:50  Business        Katunayake
# 1154 2016-12-31 22:08:00  12/31/2016 23:51  Business           Gampaha
# 1155                 NaT               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*    MILES_CAT  nc
# ...

# %%
uber_data.drop(columns='MILES_CAT')
# Out:
#              START_DATE*         END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00    1/1/2016 21:17  Business       Fort Pierce
# 1    2016-01-02 01:25:00     1/2/2016 1:37  Business       Fort Pierce
# 2    2016-01-02 20:25:00    1/2/2016 20:38  Business       Fort Pierce
# 3    2016-01-05 17:31:00    1/5/2016 17:45  Business       Fort Pierce
# 4    2016-01-06 14:42:00    1/6/2016 15:49  Business       Fort Pierce
# ...                  ...               ...       ...               ...
# 1151 2016-12-31 13:24:00  12/31/2016 13:42  Business           Kar?chi
# 1152 2016-12-31 15:03:00  12/31/2016 15:38  Business  Unknown Location
# 1153 2016-12-31 21:32:00  12/31/2016 21:50  Business        Katunayake
# 1154 2016-12-31 22:08:00  12/31/2016 23:51  Business           Gampaha
# 1155                 NaT               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*  nc
# 0          Fort Pierce      5.1   Meal/Entertain  10
# ...

# %%
uber_data.groupby('START*')['MILES*'].agg('mean')
# Out:
# START*
# Agnew                2.775000
# Almond              15.200000
# Apex                 5.341176
# Arabi               17.000000
# Arlington            4.900000
#                       ...
# West University      2.200000
# Weston               4.000000
# Westpark Place       2.182353
# Whitebridge          4.020588
# Winston Salem      133.600000
# Name: MILES*, Length: 177, dtype: float64
